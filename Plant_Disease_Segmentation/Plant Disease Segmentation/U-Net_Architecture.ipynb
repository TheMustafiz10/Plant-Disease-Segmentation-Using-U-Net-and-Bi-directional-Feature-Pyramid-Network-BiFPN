# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras import layers, Model, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model

# %%
# Data paths
TRAIN_PATH = '/kaggle/input/plant-dataset/plantsegv2/images/train'
TRAIN_MASK_PATH = '/kaggle/input/plant-dataset/plantsegv2/annotations/train'

VAL_PATH = '/kaggle/input/plant-dataset/plantsegv2/images/val'
VAL_MASK_PATH = '/kaggle/input/plant-dataset/plantsegv2/annotations/val'

TEST_PATH = '/kaggle/input/plant-dataset/plantsegv2/images/test'
TEST_MASK_PATH = '/kaggle/input/plant-dataset/plantsegv2/annotations/test'

# Parameters
IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 3

# Function to load images and masks
def load_data(image_path, mask_path, img_height, img_width):
    images = []
    masks = []
    for image_name in sorted(os.listdir(image_path)):
        img = load_img(os.path.join(image_path, image_name), target_size=(img_height, img_width))
        images.append(img_to_array(img) / 255.0)  # Normalize images

    for mask_name in sorted(os.listdir(mask_path)):
        mask = load_img(os.path.join(mask_path, mask_name), target_size=(img_height, img_width), color_mode='grayscale')
        masks.append((img_to_array(mask) > 0).astype(np.float32))  # Binarize masks

    return np.array(images), np.array(masks)

# Load train, validation, and test datasets
x_train, y_train = load_data(TRAIN_PATH, TRAIN_MASK_PATH, IMG_HEIGHT, IMG_WIDTH)
x_val, y_val = load_data(VAL_PATH, VAL_MASK_PATH, IMG_HEIGHT, IMG_WIDTH)
x_test, y_test = load_data(TEST_PATH, TEST_MASK_PATH, IMG_HEIGHT, IMG_WIDTH)

print(f"Train data: {x_train.shape}, {y_train.shape}")
print(f"Validation data: {x_val.shape}, {y_val.shape}")
print(f"Test data: {x_test.shape}, {y_test.shape}")
# Out:
# Train data: (7916, 128, 128, 3), (7916, 128, 128, 1)
# Validation data: (1247, 128, 128, 3), (1247, 128, 128, 1)
# Test data: (2295, 128, 128, 3), (2295, 128, 128, 1)

# %%
# U-Net Model
def unet(input_shape=(128, 128, 3), l2_lambda=1e-4):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(inputs)
    c1 = layers.BatchNormalization()(c1)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(c1)
    c1 = layers.BatchNormalization()(c1)
    c1 = layers.Dropout(0.1)(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(p1)
    c2 = layers.BatchNormalization()(c2)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(c2)
    c2 = layers.BatchNormalization()(c2)
    c2 = layers.Dropout(0.1)(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(256, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(p2)
    c3 = layers.BatchNormalization()(c3)
    c3 = layers.Conv2D(256, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(c3)
    c3 = layers.BatchNormalization()(c3)
    c3 = layers.Dropout(0.2)(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(512, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(p3)
    c4 = layers.BatchNormalization()(c4)
    c4 = layers.Conv2D(512, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(c4)
    c4 = layers.BatchNormalization()(c4)
    c4 = layers.Dropout(0.2)(c4)
    p4 = layers.MaxPooling2D((2, 2))(c4)

    # Bottleneck
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(p4)
    c5 = layers.BatchNormalization()(c5)
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(c5)
    c5 = layers.BatchNormalization()(c5)
    c5 = layers.Dropout(0.3)(c5)

    # Decoder
    u6 = layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(512, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(u6)
    c6 = layers.BatchNormalization()(c6)
    c6 = layers.Conv2D(512, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(c6)
    c6 = layers.BatchNormalization()(c6)
    c6 = layers.Dropout(0.2)(c6)

    u7 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(256, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(u7)
    c7 = layers.BatchNormalization()(c7)
    c7 = layers.Conv2D(256, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(c7)
    c7 = layers.BatchNormalization()(c7)
    c7 = layers.Dropout(0.2)(c7)

    u8 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(u8)
    c8 = layers.BatchNormalization()(c8)
    c8 = layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(c8)
    c8 = layers.BatchNormalization()(c8)
    c8 = layers.Dropout(0.1)(c8)

    u9 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1])
    c9 = layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(u9)
    c9 = layers.BatchNormalization()(c9)
    c9 = layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_lambda), padding='same')(c9)
    c9 = layers.BatchNormalization()(c9)
    c9 = layers.Dropout(0.1)(c9)

    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs, outputs)
    return model

# Compile the model
model = unet(input_shape=(128, 128, 3))
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.000001)
optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer=optimizer, loss=tf.keras.losses.Dice(), metrics=['accuracy', tf.keras.metrics.IoU(num_classes=1,target_class_ids=[0])])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=150,
    batch_size=16,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 233s 371ms/step - accuracy: 0.6621 - io_u: 1.0000 - loss: 0.7246 - val_accuracy: 0.8025 - val_io_u: 1.0000 - val_loss: 0.7908 - learning_rate: 0.0010
# Epoch 2/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.7353 - io_u: 1.0000 - loss: 0.5156 - val_accuracy: 0.8055 - val_io_u: 1.0000 - val_loss: 0.9278 - learning_rate: 0.0010
# Epoch 3/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.7493 - io_u: 1.0000 - loss: 0.5092 - val_accuracy: 0.5925 - val_io_u: 1.0000 - val_loss: 0.6015 - learning_rate: 0.0010
# Epoch 4/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.7526 - io_u: 1.0000 - loss: 0.5010 - val_accuracy: 0.8187 - val_io_u: 1.0000 - val_loss: 0.6664 - learning_rate: 0.0010
# Epoch 5/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.7595 - io_u: 1.0000 - loss: 0.4995 - val_accuracy: 0.6769 - val_io_u: 1.0000 - val_loss: 0.5533 - learning_rate: 0.0010
# Epoch 6/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.7665 - io_u: 1.0000 - loss: 0.4891 - val_accuracy: 0.7902 - val_io_u: 1.0000 - val_loss: 0.5003 - learning_rate: 0.0010
# Epoch 7/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.7773 - io_u: 1.0000 - loss: 0.4853 - val_accuracy: 0.8244 - val_io_u: 1.0000 - val_loss: 0.5592 - learning_rate: 0.0010
# Epoch 8/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.7768 - io_u: 1.0000 - loss: 0.4875 - val_accuracy: 0.7974 - val_io_u: 1.0000 - val_loss: 0.5302 - learning_rate: 0.0010
# Epoch 9/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.7776 - io_u: 1.0000 - loss: 0.4841 - val_accuracy: 0.8160 - val_io_u: 1.0000 - val_loss: 0.7761 - learning_rate: 0.0010
# Epoch 10/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.7803 - io_u: 1.0000 - loss: 0.4888 - val_accuracy: 0.8062 - val_io_u: 1.0000 - val_loss: 0.5353 - learning_rate: 0.0010
# Epoch 11/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.7868 - io_u: 1.0000 - loss: 0.4775 - val_accuracy: 0.7940 - val_io_u: 1.0000 - val_loss: 0.4902 - learning_rate: 0.0010
# Epoch 12/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.7909 - io_u: 1.0000 - loss: 0.4694 - val_accuracy: 0.8146 - val_io_u: 1.0000 - val_loss: 0.6116 - learning_rate: 0.0010
# Epoch 13/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.7903 - io_u: 1.0000 - loss: 0.4733 - val_accuracy: 0.8173 - val_io_u: 1.0000 - val_loss: 0.6093 - learning_rate: 0.0010
# Epoch 14/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.8018 - io_u: 1.0000 - loss: 0.4668 - val_accuracy: 0.8145 - val_io_u: 1.0000 - val_loss: 0.5088 - learning_rate: 0.0010
# Epoch 15/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.8064 - io_u: 1.0000 - loss: 0.4597 - val_accuracy: 0.7657 - val_io_u: 1.0000 - val_loss: 0.5276 - learning_rate: 0.0010
# Epoch 16/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.8101 - io_u: 1.0000 - loss: 0.4507 - val_accuracy: 0.8190 - val_io_u: 1.0000 - val_loss: 0.4750 - learning_rate: 0.0010
# Epoch 17/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.8204 - io_u: 1.0000 - loss: 0.4304 - val_accuracy: 0.8056 - val_io_u: 1.0000 - val_loss: 0.5137 - learning_rate: 0.0010
# Epoch 18/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.8179 - io_u: 1.0000 - loss: 0.4311 - val_accuracy: 0.7639 - val_io_u: 1.0000 - val_loss: 0.5027 - learning_rate: 0.0010
# Epoch 19/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.8210 - io_u: 1.0000 - loss: 0.4323 - val_accuracy: 0.8148 - val_io_u: 1.0000 - val_loss: 0.4711 - learning_rate: 0.0010
# Epoch 20/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.8263 - io_u: 1.0000 - loss: 0.4216 - val_accuracy: 0.8517 - val_io_u: 1.0000 - val_loss: 0.5237 - learning_rate: 0.0010
# Epoch 21/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.8280 - io_u: 1.0000 - loss: 0.4222 - val_accuracy: 0.7561 - val_io_u: 1.0000 - val_loss: 0.5030 - learning_rate: 0.0010
# Epoch 22/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.8274 - io_u: 1.0000 - loss: 0.4215 - val_accuracy: 0.8420 - val_io_u: 1.0000 - val_loss: 0.4424 - learning_rate: 0.0010
# Epoch 23/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.8346 - io_u: 1.0000 - loss: 0.4162 - val_accuracy: 0.7840 - val_io_u: 1.0000 - val_loss: 0.4792 - learning_rate: 0.0010
# Epoch 24/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.8354 - io_u: 1.0000 - loss: 0.4126 - val_accuracy: 0.7625 - val_io_u: 1.0000 - val_loss: 0.4938 - learning_rate: 0.0010
# Epoch 25/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.8391 - io_u: 1.0000 - loss: 0.4204 - val_accuracy: 0.8141 - val_io_u: 1.0000 - val_loss: 0.4671 - learning_rate: 0.0010
# Epoch 26/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.8352 - io_u: 1.0000 - loss: 0.4046 - val_accuracy: 0.7923 - val_io_u: 1.0000 - val_loss: 0.4770 - learning_rate: 0.0010
# Epoch 27/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.8409 - io_u: 1.0000 - loss: 0.4020 - val_accuracy: 0.8347 - val_io_u: 1.0000 - val_loss: 0.4972 - learning_rate: 0.0010
# Epoch 28/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 253ms/step - accuracy: 0.8487 - io_u: 1.0000 - loss: 0.3763 - val_accuracy: 0.8382 - val_io_u: 1.0000 - val_loss: 0.4293 - learning_rate: 5.0000e-04
# Epoch 29/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.8513 - io_u: 1.0000 - loss: 0.3741 - val_accuracy: 0.8407 - val_io_u: 1.0000 - val_loss: 0.4089 - learning_rate: 5.0000e-04
# Epoch 30/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 251ms/step - accuracy: 0.8542 - io_u: 1.0000 - loss: 0.3637 - val_accuracy: 0.8527 - val_io_u: 1.0000 - val_loss: 0.4123 - learning_rate: 5.0000e-04
# Epoch 31/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.8541 - io_u: 1.0000 - loss: 0.3573 - val_accuracy: 0.8280 - val_io_u: 1.0000 - val_loss: 0.4215 - learning_rate: 5.0000e-04
# Epoch 32/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 125s 252ms/step - accuracy: 0.8597 - io_u: 1.0000 - loss: 0.3533 - val_accuracy: 0.8556 - val_io_u: 1.0000 - val_loss: 0.3967 - learning_rate: 5.0000e-04
# Epoch 33/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8562 - io_u: 1.0000 - loss: 0.3558 - val_accuracy: 0.8430 - val_io_u: 1.0000 - val_loss: 0.4082 - learning_rate: 5.0000e-04
# Epoch 34/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8612 - io_u: 1.0000 - loss: 0.3479 - val_accuracy: 0.8591 - val_io_u: 1.0000 - val_loss: 0.3942 - learning_rate: 5.0000e-04
# Epoch 35/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 251ms/step - accuracy: 0.8578 - io_u: 1.0000 - loss: 0.3532 - val_accuracy: 0.8571 - val_io_u: 1.0000 - val_loss: 0.4131 - learning_rate: 5.0000e-04
# Epoch 36/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 251ms/step - accuracy: 0.8639 - io_u: 1.0000 - loss: 0.3455 - val_accuracy: 0.8701 - val_io_u: 1.0000 - val_loss: 0.3935 - learning_rate: 5.0000e-04
# Epoch 37/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8621 - io_u: 1.0000 - loss: 0.3501 - val_accuracy: 0.8646 - val_io_u: 1.0000 - val_loss: 0.4142 - learning_rate: 5.0000e-04
# Epoch 38/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 251ms/step - accuracy: 0.8652 - io_u: 1.0000 - loss: 0.3434 - val_accuracy: 0.8539 - val_io_u: 1.0000 - val_loss: 0.5255 - learning_rate: 5.0000e-04
# Epoch 39/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8651 - io_u: 1.0000 - loss: 0.3488 - val_accuracy: 0.8622 - val_io_u: 1.0000 - val_loss: 0.4663 - learning_rate: 5.0000e-04
# Epoch 40/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8692 - io_u: 1.0000 - loss: 0.3369 - val_accuracy: 0.8622 - val_io_u: 1.0000 - val_loss: 0.3961 - learning_rate: 5.0000e-04
# Epoch 41/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 251ms/step - accuracy: 0.8666 - io_u: 1.0000 - loss: 0.3372 - val_accuracy: 0.8705 - val_io_u: 1.0000 - val_loss: 0.4122 - learning_rate: 5.0000e-04
# Epoch 42/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 251ms/step - accuracy: 0.8760 - io_u: 1.0000 - loss: 0.3203 - val_accuracy: 0.8686 - val_io_u: 1.0000 - val_loss: 0.4723 - learning_rate: 2.5000e-04
# Epoch 43/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8800 - io_u: 1.0000 - loss: 0.3082 - val_accuracy: 0.8305 - val_io_u: 1.0000 - val_loss: 0.4060 - learning_rate: 2.5000e-04
# Epoch 44/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 251ms/step - accuracy: 0.8828 - io_u: 1.0000 - loss: 0.3036 - val_accuracy: 0.8239 - val_io_u: 1.0000 - val_loss: 0.4096 - learning_rate: 2.5000e-04
# Epoch 45/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 251ms/step - accuracy: 0.8813 - io_u: 1.0000 - loss: 0.3029 - val_accuracy: 0.8631 - val_io_u: 1.0000 - val_loss: 0.3837 - learning_rate: 2.5000e-04
# Epoch 46/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8834 - io_u: 1.0000 - loss: 0.3047 - val_accuracy: 0.8582 - val_io_u: 1.0000 - val_loss: 0.3835 - learning_rate: 2.5000e-04
# Epoch 47/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8854 - io_u: 1.0000 - loss: 0.2990 - val_accuracy: 0.8328 - val_io_u: 1.0000 - val_loss: 0.3949 - learning_rate: 2.5000e-04
# Epoch 48/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 251ms/step - accuracy: 0.8887 - io_u: 1.0000 - loss: 0.2970 - val_accuracy: 0.8680 - val_io_u: 1.0000 - val_loss: 0.3699 - learning_rate: 2.5000e-04
# Epoch 49/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8895 - io_u: 1.0000 - loss: 0.3002 - val_accuracy: 0.8535 - val_io_u: 1.0000 - val_loss: 0.3776 - learning_rate: 2.5000e-04
# Epoch 50/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8908 - io_u: 1.0000 - loss: 0.2900 - val_accuracy: 0.8559 - val_io_u: 1.0000 - val_loss: 0.3827 - learning_rate: 2.5000e-04
# Epoch 51/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8943 - io_u: 1.0000 - loss: 0.2898 - val_accuracy: 0.8656 - val_io_u: 1.0000 - val_loss: 0.3736 - learning_rate: 2.5000e-04
# Epoch 52/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8940 - io_u: 1.0000 - loss: 0.2850 - val_accuracy: 0.8551 - val_io_u: 1.0000 - val_loss: 0.3840 - learning_rate: 2.5000e-04
# Epoch 53/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8915 - io_u: 1.0000 - loss: 0.2885 - val_accuracy: 0.8677 - val_io_u: 1.0000 - val_loss: 0.3746 - learning_rate: 2.5000e-04
# Epoch 54/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.8990 - io_u: 1.0000 - loss: 0.2793 - val_accuracy: 0.8589 - val_io_u: 1.0000 - val_loss: 0.3693 - learning_rate: 1.2500e-04
# Epoch 55/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9045 - io_u: 1.0000 - loss: 0.2605 - val_accuracy: 0.8654 - val_io_u: 1.0000 - val_loss: 0.3671 - learning_rate: 1.2500e-04
# Epoch 56/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9070 - io_u: 1.0000 - loss: 0.2571 - val_accuracy: 0.8607 - val_io_u: 1.0000 - val_loss: 0.3721 - learning_rate: 1.2500e-04
# Epoch 57/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9057 - io_u: 1.0000 - loss: 0.2553 - val_accuracy: 0.8713 - val_io_u: 1.0000 - val_loss: 0.3675 - learning_rate: 1.2500e-04
# Epoch 58/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9086 - io_u: 1.0000 - loss: 0.2512 - val_accuracy: 0.8661 - val_io_u: 1.0000 - val_loss: 0.3665 - learning_rate: 1.2500e-04
# Epoch 59/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9075 - io_u: 1.0000 - loss: 0.2527 - val_accuracy: 0.8719 - val_io_u: 1.0000 - val_loss: 0.3630 - learning_rate: 1.2500e-04
# Epoch 60/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9093 - io_u: 1.0000 - loss: 0.2532 - val_accuracy: 0.8580 - val_io_u: 1.0000 - val_loss: 0.3743 - learning_rate: 1.2500e-04
# Epoch 61/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9104 - io_u: 1.0000 - loss: 0.2461 - val_accuracy: 0.8719 - val_io_u: 1.0000 - val_loss: 0.3659 - learning_rate: 1.2500e-04
# Epoch 62/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9114 - io_u: 1.0000 - loss: 0.2477 - val_accuracy: 0.8539 - val_io_u: 1.0000 - val_loss: 0.3756 - learning_rate: 1.2500e-04
# Epoch 63/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9133 - io_u: 1.0000 - loss: 0.2413 - val_accuracy: 0.8730 - val_io_u: 1.0000 - val_loss: 0.3745 - learning_rate: 1.2500e-04
# Epoch 64/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9135 - io_u: 1.0000 - loss: 0.2397 - val_accuracy: 0.8504 - val_io_u: 1.0000 - val_loss: 0.3748 - learning_rate: 1.2500e-04
# Epoch 65/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9131 - io_u: 1.0000 - loss: 0.2371 - val_accuracy: 0.8728 - val_io_u: 1.0000 - val_loss: 0.3620 - learning_rate: 6.2500e-05
# Epoch 66/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9174 - io_u: 1.0000 - loss: 0.2308 - val_accuracy: 0.8738 - val_io_u: 1.0000 - val_loss: 0.3639 - learning_rate: 6.2500e-05
# Epoch 67/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9180 - io_u: 1.0000 - loss: 0.2304 - val_accuracy: 0.8756 - val_io_u: 1.0000 - val_loss: 0.3610 - learning_rate: 6.2500e-05
# Epoch 68/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9187 - io_u: 1.0000 - loss: 0.2348 - val_accuracy: 0.8780 - val_io_u: 1.0000 - val_loss: 0.3636 - learning_rate: 6.2500e-05
# Epoch 69/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9178 - io_u: 1.0000 - loss: 0.2276 - val_accuracy: 0.8701 - val_io_u: 1.0000 - val_loss: 0.3599 - learning_rate: 6.2500e-05
# Epoch 70/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9184 - io_u: 1.0000 - loss: 0.2271 - val_accuracy: 0.8788 - val_io_u: 1.0000 - val_loss: 0.3607 - learning_rate: 6.2500e-05
# Epoch 71/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9216 - io_u: 1.0000 - loss: 0.2243 - val_accuracy: 0.8712 - val_io_u: 1.0000 - val_loss: 0.3591 - learning_rate: 6.2500e-05
# Epoch 72/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9225 - io_u: 1.0000 - loss: 0.2168 - val_accuracy: 0.8768 - val_io_u: 1.0000 - val_loss: 0.3604 - learning_rate: 6.2500e-05
# Epoch 73/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9222 - io_u: 1.0000 - loss: 0.2164 - val_accuracy: 0.8732 - val_io_u: 1.0000 - val_loss: 0.3584 - learning_rate: 6.2500e-05
# Epoch 74/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9226 - io_u: 1.0000 - loss: 0.2177 - val_accuracy: 0.8746 - val_io_u: 1.0000 - val_loss: 0.3578 - learning_rate: 6.2500e-05
# Epoch 75/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9228 - io_u: 1.0000 - loss: 0.2160 - val_accuracy: 0.8801 - val_io_u: 1.0000 - val_loss: 0.3681 - learning_rate: 6.2500e-05
# Epoch 76/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9237 - io_u: 1.0000 - loss: 0.2134 - val_accuracy: 0.8796 - val_io_u: 1.0000 - val_loss: 0.3846 - learning_rate: 6.2500e-05
# Epoch 77/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 248ms/step - accuracy: 0.9221 - io_u: 1.0000 - loss: 0.2159 - val_accuracy: 0.8689 - val_io_u: 1.0000 - val_loss: 0.3637 - learning_rate: 6.2500e-05
# Epoch 78/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9244 - io_u: 1.0000 - loss: 0.2149 - val_accuracy: 0.8735 - val_io_u: 1.0000 - val_loss: 0.3631 - learning_rate: 6.2500e-05
# Epoch 79/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9248 - io_u: 1.0000 - loss: 0.2141 - val_accuracy: 0.8751 - val_io_u: 1.0000 - val_loss: 0.3537 - learning_rate: 6.2500e-05
# Epoch 80/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9265 - io_u: 1.0000 - loss: 0.2061 - val_accuracy: 0.8753 - val_io_u: 1.0000 - val_loss: 0.3580 - learning_rate: 6.2500e-05
# Epoch 81/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9265 - io_u: 1.0000 - loss: 0.2109 - val_accuracy: 0.8725 - val_io_u: 1.0000 - val_loss: 0.3606 - learning_rate: 6.2500e-05
# Epoch 82/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9258 - io_u: 1.0000 - loss: 0.2117 - val_accuracy: 0.8769 - val_io_u: 1.0000 - val_loss: 0.3716 - learning_rate: 6.2500e-05
# Epoch 83/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9265 - io_u: 1.0000 - loss: 0.2132 - val_accuracy: 0.8728 - val_io_u: 1.0000 - val_loss: 0.3605 - learning_rate: 6.2500e-05
# Epoch 84/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9298 - io_u: 1.0000 - loss: 0.2032 - val_accuracy: 0.8777 - val_io_u: 1.0000 - val_loss: 0.3585 - learning_rate: 6.2500e-05
# Epoch 85/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9306 - io_u: 1.0000 - loss: 0.2036 - val_accuracy: 0.8716 - val_io_u: 1.0000 - val_loss: 0.3592 - learning_rate: 3.1250e-05
# Epoch 86/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 249ms/step - accuracy: 0.9324 - io_u: 1.0000 - loss: 0.1971 - val_accuracy: 0.8751 - val_io_u: 1.0000 - val_loss: 0.3574 - learning_rate: 3.1250e-05
# Epoch 87/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 123s 249ms/step - accuracy: 0.9313 - io_u: 1.0000 - loss: 0.1988 - val_accuracy: 0.8739 - val_io_u: 1.0000 - val_loss: 0.3638 - learning_rate: 3.1250e-05
# Epoch 88/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9315 - io_u: 1.0000 - loss: 0.1975 - val_accuracy: 0.8766 - val_io_u: 1.0000 - val_loss: 0.3589 - learning_rate: 3.1250e-05
# Epoch 89/150
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 124s 250ms/step - accuracy: 0.9349 - io_u: 1.0000 - loss: 0.1892 - val_accuracy: 0.8738 - val_io_u: 1.0000 - val_loss: 0.3616 - learning_rate: 3.1250e-05

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 128, 128, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 128, 128, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 128, 128, 64)   │         36,928 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 128, 128, 64)   │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 128, 128, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 64, 64, 64)     │              0 │ dropout[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 64, 64, 128)    │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 64, 64, 128)    │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 64, 64, 128)    │        147,584 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 64, 64, 128)    │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 64, 64, 128)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 32, 32, 128)    │              0 │ dropout_1[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 32, 32, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 32, 32, 256)    │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 32, 32, 256)    │        590,080 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 32, 32, 256)    │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 32, 32, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 16, 16, 256)    │              0 │ dropout_2[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 16, 16, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 16, 16, 512)    │          2,048 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 16, 16, 512)    │      2,359,808 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 16, 16, 512)    │          2,048 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 16, 16, 512)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 8, 8, 512)      │              0 │ dropout_3[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 8, 8, 1024)     │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 8, 8, 1024)     │          4,096 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 8, 8, 1024)     │      9,438,208 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 8, 8, 1024)     │          4,096 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 8, 8, 1024)     │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 512)    │      2,097,664 │ dropout_4[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 16, 16, 1024)   │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 16, 16, 512)    │      4,719,104 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 16, 16, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 16, 16, 512)    │          2,048 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 256)    │        524,544 │ dropout_5[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 32, 32, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 32, 32, 256)    │      1,179,904 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 32, 32, 256)    │          1,024 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 32, 32, 256)    │        590,080 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 32, 32, 256)    │          1,024 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 64, 128)    │        131,200 │ dropout_6[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 64, 64, 256)    │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 64, 64, 128)    │        295,040 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 64, 64, 128)    │            512 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 64, 64, 128)    │        147,584 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 64, 64, 128)    │            512 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 64, 64, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 128, 128, 64)   │         32,832 │ dropout_7[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 128, 128, 128)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 128, 128, 64)   │         73,792 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 128, 128, 64)   │            256 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 128, 128, 64)   │         36,928 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 128, 128, 64)   │            256 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 128, 128, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 128, 128, 1)    │             65 │ dropout_8[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 93,142,341 (355.31 MB)
#  Trainable params: 31,043,521 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)
#  Optimizer params: 62,087,044 (236.84 MB)

# %%
# Save

model.save('unet_model.h5')

# %%
# Visualize predictions
def visualize_predictions(images, masks, model, n_samples=5):
    predictions = model.predict(images[:n_samples])
    for i in range(n_samples):
        plt.figure(figsize=(10, 5))

        plt.subplot(1, 3, 1)
        plt.title("Image")
        plt.imshow(images[i])

        plt.subplot(1, 3, 2)
        plt.title("Ground Truth")
        plt.imshow(masks[i].squeeze(), cmap='gray')

        plt.subplot(1, 3, 3)
        plt.title("Prediction")
        plt.imshow(predictions[i].squeeze(), cmap='gray')

        plt.show()

visualize_predictions(x_test, y_test, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step

# %%
# Custom metric: Mean Intersection Over Union (mIoU)
def mean_iou(y_true, y_pred):
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.reduce_mean((intersection + 1e-7) / (union + 1e-7), axis=0)
    return iou

# Custom metric: Dice Coefficient
def dice_coefficient(y_true, y_pred):
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    dice = (2. * intersection + 1e-7) / (tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) + 1e-7)
    return tf.reduce_mean(dice, axis=0)

# Custom metric: Pixel Accuracy
def pixel_accuracy(y_true, y_pred):
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    correct = tf.reduce_sum(tf.cast(y_true == y_pred, tf.float32), axis=[1, 2, 3])
    total = tf.cast(tf.size(y_true[0, :, :, 0]), tf.float32)
    accuracy = correct / total
    return tf.reduce_mean(accuracy, axis=0)

# Evaluate model and calculate metrics
def evaluate_model(model, x, y):
    preds = model.predict(x)
    iou = mean_iou(y, preds).numpy()
    dice = dice_coefficient(y, preds).numpy()
    accuracy = pixel_accuracy(y, preds).numpy()
    return iou, dice, accuracy

# Evaluate on each dataset
train_iou, train_dice, train_acc = evaluate_model(model, x_train, y_train)
val_iou, val_dice, val_acc = evaluate_model(model, x_val, y_val)
test_iou, test_dice, test_acc = evaluate_model(model, x_test, y_test)

print(f"Train - mIoU: {train_iou:.4f}, Dice: {train_dice:.4f}, Accuracy: {train_acc:.4f}")
print(f"Validation - mIoU: {val_iou:.4f}, Dice: {val_dice:.4f}, Accuracy: {val_acc:.4f}")
print(f"Test - mIoU: {test_iou:.4f}, Dice: {test_dice:.4f}, Accuracy: {test_acc:.4f}")
# Out:
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 58s 159ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 563ms/step
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 23s 330ms/step
# Train - mIoU: 0.5937, Dice: 0.7034, Accuracy: 0.9288
# Validation - mIoU: 0.4698, Dice: 0.5881, Accuracy: 0.8751
# Test - mIoU: 0.4757, Dice: 0.5923, Accuracy: 0.8726

# %%
# Overlay segmentation mask on image
def overlay_mask(image, mask, alpha=0.4, color=(0, 1, 0)):
    overlay = np.zeros_like(image)
    overlay[:, :, 1] = mask.squeeze() * color[1]  # Apply color to mask
    return np.clip(image + alpha * overlay, 0, 1)

# Identify good and bad examples
def find_examples(images, masks, preds, n_examples=3, threshold=0.7):
    ious = [mean_iou(np.expand_dims(true, 0), np.expand_dims(pred, 0)).numpy()
            for true, pred in zip(masks, preds)]
    sorted_indices = np.argsort(ious)  # Sort by IoU
    good_indices = sorted_indices[-n_examples:]  # Best IoUs
    bad_indices = sorted_indices[:n_examples]  # Worst IoUs
    return good_indices, bad_indices

# %%
# Predictions
test_preds = model.predict(x_test)

# Find good and bad examples
good_indices, bad_indices = find_examples(x_test, y_test, test_preds, n_examples=3)

# Visualize examples
def visualize_examples(images, masks, preds, indices, title):
    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.suptitle(title, fontsize=16)

        plt.subplot(1, 3, 1)
        plt.title("Image")
        plt.imshow(images[i])

        plt.subplot(1, 3, 2)
        plt.title("Ground Truth")
        plt.imshow(masks[i].squeeze(), cmap='gray')

        plt.subplot(1, 3, 3)
        plt.title("Prediction")
        plt.imshow(preds[i].squeeze(), cmap='gray')

        plt.show()

# Visualize good examples
visualize_examples(x_test, y_test, test_preds, good_indices, "Good Segmentation Examples")

# Visualize bad examples
visualize_examples(x_test, y_test, test_preds, bad_indices, "Bad Segmentation Examples")
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step
